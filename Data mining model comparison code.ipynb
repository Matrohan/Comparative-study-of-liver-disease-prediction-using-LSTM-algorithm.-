# %%
# importing data mining/cleaning/exploratory libraries and modules
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px
import numpy as np
import matplotlib
import plotly

sns.set(rc={'figure.figsize':(6,5)})

# %%
# checking pandas version
pd.__version__
# checking matplotlib version
matplotlib.__version__
# checking seaborn version
sns.__version__
# checking plotly version
plotly.__version__
# checking numpy version
np.__version__
# Out:
# '1.20.3'

# %% [markdown]
# # Data Cleaning And Exploration Phase:

# %%
# reading in dataset
df = pd.read_csv('liver_patient .csv')
display(df.head())
display(df.tail())
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# 1      3.2                        0.74        1
# 2      3.3                        0.89        1
# 3      3.4                        1.00        1
# 4      2.4                        0.40        1
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 578   60   Male              0.5               0.1                   500
# 579   40   Male              0.6               0.1                    98
# 580   52   Male              0.8               0.2                   245
# 581   31   Male              1.3               0.5                   184
# 582   38   Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# 578      1.6                        0.37        2
# 579      3.2                        1.10        1
# 580      3.2                        1.00        1
# 581      3.4                        1.00        1
# 582      4.4                        1.50        2

# %%
# getting dataset shape
df.shape
# Out:
# (583, 11)

# %%
# getting dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    object
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  579 non-null    float64
#  10  Dataset                     583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
# getting dataset description
df.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# std                  182.620356                  288.918529        1.085451
# min                   10.000000                   10.000000        2.700000
# 25%                   23.000000                   25.000000        5.800000
# 50%                   35.000000                   42.000000        6.600000
# 75%                   60.500000                   87.000000        7.200000
# max                 2000.000000                 4929.000000        9.600000
#
#           Albumin  Albumin_and_Globulin_Ratio     Dataset
# count  583.000000                  579.000000  583.000000
# mean     3.141852                    0.947064    1.286449
# std      0.795519                    0.319592    0.452490
# min      0.900000                    0.300000    1.000000
# 25%      2.600000                    0.700000    1.000000
# 50%      3.100000                    0.930000    1.000000
# 75%      3.800000                    1.100000    2.000000
# max      5.500000                    2.800000    2.000000

# %%
# retrieving dataset columns
df.columns.tolist()
# Out:
# ['Age',
#  'Gender',
#  'Total_Bilirubin',
#  'Direct_Bilirubin',
#  'Alkaline_Phosphotase',
#  'Alamine_Aminotransferase',
#  'Aspartate_Aminotransferase',
#  'Total_Protiens',
#  'Albumin',
#  'Albumin_and_Globulin_Ratio',
#  'Dataset']

# %%
# retrieving dataset data types
df.dtypes
# Out:
# Age                             int64
# Gender                         object
# Total_Bilirubin               float64
# Direct_Bilirubin              float64
# Alkaline_Phosphotase            int64
# Alamine_Aminotransferase        int64
# Aspartate_Aminotransferase      int64
# Total_Protiens                float64
# Albumin                       float64
# Albumin_and_Globulin_Ratio    float64
# Dataset                         int64
# dtype: object

# %% [markdown]
# Creating visualizations and cleaning dataset:

# %%
# creating dataset correlation heatmap
sns.heatmap(df.corr(), cmap='GnBu', linewidths=.5);

# %%
# retrieving dataset correlations
df.corr()
# Out:
#                                  Age  Total_Bilirubin  Direct_Bilirubin  \
# Age                         1.000000         0.011763          0.007529
# Total_Bilirubin             0.011763         1.000000          0.874618
# Direct_Bilirubin            0.007529         0.874618          1.000000
# Alkaline_Phosphotase        0.080425         0.206669          0.234939
# Alamine_Aminotransferase   -0.086883         0.214065          0.233894
# Aspartate_Aminotransferase -0.019910         0.237831          0.257544
# Total_Protiens             -0.187461        -0.008099         -0.000139
# Albumin                    -0.265924        -0.222250         -0.228531
# Albumin_and_Globulin_Ratio -0.216408        -0.206267         -0.200125
# Dataset                    -0.137351        -0.220208         -0.246046
#
#                             Alkaline_Phosphotase  Alamine_Aminotransferase  \
# Age                                     0.080425                 -0.086883
# Total_Bilirubin                         0.206669                  0.214065
# Direct_Bilirubin                        0.234939                  0.233894
# Alkaline_Phosphotase                    1.000000                  0.125680
# Alamine_Aminotransferase                0.125680                  1.000000
# Aspartate_Aminotransferase              0.167196                  0.791966
# Total_Protiens                         -0.028514                 -0.042518
# Albumin                                -0.165453                 -0.029742
# Albumin_and_Globulin_Ratio             -0.234166                 -0.002375
# Dataset                                -0.184866                 -0.163416
#
#                             Aspartate_Aminotransferase  Total_Protiens  \
# Age                                          -0.019910       -0.187461
# Total_Bilirubin                               0.237831       -0.008099
# Direct_Bilirubin                              0.257544       -0.000139
# Alkaline_Phosphotase                          0.167196       -0.028514
# Alamine_Aminotransferase                      0.791966       -0.042518
# Aspartate_Aminotransferase                    1.000000       -0.025645
# Total_Protiens                               -0.025645        1.000000
# Albumin                                      -0.085290        0.784053
# Albumin_and_Globulin_Ratio                   -0.070040        0.234887
# Dataset                                      -0.151934        0.035008
#
#                              Albumin  Albumin_and_Globulin_Ratio   Dataset
# Age                        -0.265924                   -0.216408 -0.137351
# Total_Bilirubin            -0.222250                   -0.206267 -0.220208
# Direct_Bilirubin           -0.228531                   -0.200125 -0.246046
# Alkaline_Phosphotase       -0.165453                   -0.234166 -0.184866
# Alamine_Aminotransferase   -0.029742                   -0.002375 -0.163416
# Aspartate_Aminotransferase -0.085290                   -0.070040 -0.151934
# Total_Protiens              0.784053                    0.234887  0.035008
# Albumin                     1.000000                    0.689632  0.161388
# Albumin_and_Globulin_Ratio  0.689632                    1.000000  0.163131
# Dataset                     0.161388                    0.163131  1.000000

# %%
# renaming proteins columns
df = df.rename(columns={'Total_Protiens': 'Total_Proteins'})

# %%
# gender countplot
df['Gender'].value_counts().plot.bar(color='red', title='Male vs. Female Countplot');

# %%
# value counts for gender column
df['Gender'].value_counts()
# Out:
# Male      441
# Female    142
# Name: Gender, dtype: int64

# %%
#plotting a Pie plot for Gender column
plt.figure(figsize=(9,6))
df['Gender'].value_counts().plot(kind='pie',autopct='%.2f%%',colors=['goldenrod','dimgray'],explode=(0,0.2),shadow=True,wedgeprops = {'linewidth': 3})
label=['Male','Female']
plt.title('Percentage difference in the count between Male and Female')
plt.legend(label,title='Category')
plt.show()

# %%
# age value counts
sns.set_style('darkgrid')
plt.figure(figsize=(25,10))
df['Age'].value_counts().plot.bar(color='cornflowerblue', title='Age Value Counts');

# %%
#

# %%
# value counts for age column
df['Age'].value_counts()
# Out:
# 60    34
# 45    25
# 50    23
# 42    21
# 38    21
#       ..
# 78     1
# 11     1
# 67     1
# 10     1
# 90     1
# Name: Age, Length: 72, dtype: int64

# %%
# lmplots of direct bilirubin vs. total bilirubin in terms of gender
sns.set()

g = sns.lmplot(x="Direct_Bilirubin", y="Total_Bilirubin", hue="Gender",
               height=5, data=df,  palette="Set1")

g.set_axis_labels("Direct_Bilirubin", "Total_Bilirubin");

# %%
# correlation direct bilirubin vs. total bilirubin
df['Direct_Bilirubin'].corr(df['Total_Bilirubin'])
# Out:
# 0.8746179301164134

# %%
# lmplot of alamine aminotransferase vs. aspartate aminotransferase in terms of gender 
sns.set()

g = sns.lmplot(x="Alamine_Aminotransferase", y="Aspartate_Aminotransferase", hue='Gender',
               height=5, data=df,  palette="Set2")

g.set_axis_labels("Alamaine_Aminotransferase", "Aspartate_Aminotransferase");

# %%
# correlation alamine aminotransferase vs. aspartate aminotransferace
df['Alamine_Aminotransferase'].corr(df['Aspartate_Aminotransferase'])
# Out:
# 0.7919656848536131

# %%
# lmplot of total proteins vs. albumin in terms of gender
sns.set()

g = sns.lmplot(x="Total_Proteins", y="Albumin", hue='Gender',
               height=5, data=df,  palette="Set3")

g.set_axis_labels("Total_Proteins", "Albumin");

# %%
# correlation total proteins vs. albumin
df['Total_Proteins'].corr(df['Albumin'])
# Out:
# 0.7840533353871909

# %%
# lmplot of albumin vs. albumin and globulin ratio in terms gender
sns.set()

g = sns.lmplot(x="Albumin", y="Albumin_and_Globulin_Ratio", hue='Gender',
               height=5, data=df)

g.set_axis_labels("Albumin", "Albumin_and_Globulin_Ratio");

# %%
# correlation albumin vs. albumin and globulin ratio
df['Albumin'].corr(df['Albumin_and_Globulin_Ratio'])
# Out:
# 0.6896323418966306

# %%
# direct bilirubin sum in terms of gender 
plt.figure(figsize=(7,5))
df.groupby('Gender').sum()['Direct_Bilirubin'].plot.bar(color='plum', title='Gender vs. Direct Bilirubin Intake');

# %%
# sums for direct bilurubin in terms of gender
df.groupby('Gender')['Direct_Bilirubin'].sum()
# Out:
# Gender
# Female    140.5
# Male      725.9
# Name: Direct_Bilirubin, dtype: float64

# %%
# total bilirubin sum in terms of gender
plt.figure(figsize=(7,5))
df.groupby('Gender').sum()['Total_Bilirubin'].plot.bar(color='cadetblue', title='Gender vs. Total Bilirubin Intake');

# %%
# sums for total bilirubin in terms of gender
df.groupby('Gender')['Total_Bilirubin'].sum()
# Out:
# Gender
# Female     329.8
# Male      1593.4
# Name: Total_Bilirubin, dtype: float64

# %%
# alamine aminotransferase sum in terms of gender
plt.figure(figsize=(7,5))
df.groupby('Gender').sum()['Alamine_Aminotransferase'].plot.bar(color='mediumslateblue', title='Gender vs. Alamine Aminotransferase Intake');

# %%
# alamine aminotransferase sum in terms of gender
plt.figure(figsize=(7,5))
df.groupby('Gender').sum()['Alamine_Aminotransferase'].plot.bar(color='mediumslateblue', title='Gender vs. Alamine Aminotransferase Intake');

# %%
# aspartate aminotransferase sum in terms of gender
plt.figure(figsize=(7,5))
df.groupby('Gender').sum()['Aspartate_Aminotransferase'].plot.bar(color='olive', title='Gender vs. Aspartate Aminotransferase Intake');

# %%
# sums for aspartate aminotransferase in terms of gender
df.groupby('Gender')['Aspartate_Aminotransferase'].sum()
# Out:
# Gender
# Female     9804
# Male      54274
# Name: Aspartate_Aminotransferase, dtype: int64

# %%
# total proteins sum in terms of gender
plt.figure(figsize=(7,5))
df.groupby('Gender').sum()['Total_Proteins'].plot.bar(color='tan', title='Gender vs. Total Protein Intake');

# %%
# sums for total proteins in terms of gender
df.groupby('Gender')['Total_Proteins'].sum()
# Out:
# Gender
# Female     944.8
# Male      2834.9
# Name: Total_Proteins, dtype: float64

# %%
# albumin sum in terms of gender
plt.figure(figsize=(7,5))
df.groupby('Gender').sum()['Albumin'].plot.bar(color='mediumseagreen', title='Gender vs. Albumin Intake');

# %%
# sums for albumin and globulin ratio in terms of gender
df.groupby('Gender')['Albumin_and_Globulin_Ratio'].sum()# sums for albumin in terms of gender
df.groupby('Gender')['Albumin'].sum()
# Out:
# Gender
# Female     464.8
# Male      1366.9
# Name: Albumin, dtype: float64

# %%
# albumin and globulin ratio sum in terms of gender
plt.figure(figsize=(7,5))
df.groupby('Gender').sum()['Albumin_and_Globulin_Ratio'].plot.bar(color='mediumvioletred', title='Gender vs. Albumin-Globulin Ratio Intake');

# %%
# sums for albumin and globulin ratio in terms of gender
df.groupby('Gender')['Albumin_and_Globulin_Ratio'].sum()
# Out:
# Gender
# Female    132.86
# Male      415.49
# Name: Albumin_and_Globulin_Ratio, dtype: float64

# %% [markdown]
# # Feature Engineering:
# Dealing with target column:

# %%
# changing dataset column to liver disease and replacing the terms
df['Liver_Disease'] = df['Dataset'].replace([1,2],[0,1])
df = df.drop('Dataset', axis=1)
df['Liver_Disease'].value_counts()
# Out:
# 0    416
# 1    167
# Name: Liver_Disease, dtype: int64

# %%
# retrieving dataframe datatypes
df.dtypes
# Out:
# Age                             int64
# Gender                         object
# Total_Bilirubin               float64
# Direct_Bilirubin              float64
# Alkaline_Phosphotase            int64
# Alamine_Aminotransferase        int64
# Aspartate_Aminotransferase      int64
# Total_Proteins                float64
# Albumin                       float64
# Albumin_and_Globulin_Ratio    float64
# Liver_Disease                   int64
# dtype: object

# %%
# countplot of liver disease in terms of gender
sns.set(style='darkgrid')

g = sns.countplot(x='Liver_Disease', hue='Gender',
                data=df, palette='bright');

# %%
# counts for liver disease in terms of gender 
df.groupby('Liver_Disease')['Gender'].value_counts()
# Out:
# Liver_Disease  Gender
# 0              Male      324
#                Female     92
# 1              Male      117
#                Female     50
# Name: Gender, dtype: int64

# %%
# liver disease value counts
df['Liver_Disease'].value_counts().plot.bar(color='magenta', title='Liver Disease Countplot');

# %%
# liver disease value counts
df['Liver_Disease'].value_counts()
# Out:
# 0    416
# 1    167
# Name: Liver_Disease, dtype: int64

# %%
# percent of people affected with liver disease
no_disease = (df['Liver_Disease'] == 0).sum()
yes_disease = (df['Liver_Disease'] == 1).sum()  

percent_disease = (yes_disease/no_disease * 100)

print('Percent of people that tested positive for liver disease is {:.2f}%'.format(percent_disease))
# Out:
# Percent of people that tested positive for liver disease is 40.14%

# %%
# percent of people that tested positive for liver disease that were male
males_percent_disease = (117/yes_disease) * 100

print('Percent of people that tested positive for liver disease that are male {:.2f}%'.format(males_percent_disease))
# Out:
# Percent of people that tested positive for liver disease that are male 70.06%

# %% [markdown]
# # Dealing with null values:

# %%
# retrieving dataset null value sum
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Proteins                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Liver_Disease                 0
# dtype: int64

# %%
# retrieving albumin and globulin ratio unique values
df['Albumin_and_Globulin_Ratio'].unique()
# Out:
# array([0.9 , 0.74, 0.89, 1.  , 0.4 , 1.3 , 1.1 , 1.2 , 0.8 , 0.6 , 0.87,
#        0.7 , 0.92, 0.55, 0.5 , 1.85, 0.95, 1.4 , 1.18, 0.61, 1.34, 1.39,
#        1.6 , 1.58, 1.25, 0.78, 0.76, 1.55, 0.71, 0.62, 0.67, 0.75, 1.16,
#        1.5 , 1.66, 0.96, 1.38, 0.52, 0.47, 0.93, 0.48, 0.58, 0.69, 1.27,
#        1.12, 1.06, 0.53, 1.03, 0.68,  nan, 1.9 , 1.7 , 1.8 , 0.3 , 0.97,
#        0.35, 1.51, 0.64, 0.45, 1.36, 0.88, 1.09, 1.11, 1.72, 2.8 , 0.46,
#        0.39, 1.02, 2.5 , 0.37])

# %%
# retrieving albumin and globulin ratio median value
df['Albumin_and_Globulin_Ratio'].median()
# Out:
# 0.93

# %%
# replacing na values from albumin and globulin ratio column with median
df.fillna(df['Albumin_and_Globulin_Ratio'].median(), inplace=True)

# %%
# retrieving null sum
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Proteins                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Liver_Disease                 0
# dtype: int64

# %%
# making dataframe copy
df1 = df.copy()

# %%
# checking null sum of new df1 dataframe
df1.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Proteins                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Liver_Disease                 0
# dtype: int64

# %%
# retrieving df1 column list
df1.columns.tolist()
# Out:
# ['Age',
#  'Gender',
#  'Total_Bilirubin',
#  'Direct_Bilirubin',
#  'Alkaline_Phosphotase',
#  'Alamine_Aminotransferase',
#  'Aspartate_Aminotransferase',
#  'Total_Proteins',
#  'Albumin',
#  'Albumin_and_Globulin_Ratio',
#  'Liver_Disease']

# %%
# retrieving df1 dataframe info
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    object
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Proteins              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  583 non-null    float64
#  10  Liver_Disease               583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %% [markdown]
# # Dealing with outliers:

# %%
# retrieving dataset datatypes
df1.dtypes
# Out:
# Age                             int64
# Gender                         object
# Total_Bilirubin               float64
# Direct_Bilirubin              float64
# Alkaline_Phosphotase            int64
# Alamine_Aminotransferase        int64
# Aspartate_Aminotransferase      int64
# Total_Proteins                float64
# Albumin                       float64
# Albumin_and_Globulin_Ratio    float64
# Liver_Disease                   int64
# dtype: object

# %%
# retrieving dataframe shape
df1.shape
# Out:
# (583, 11)

# %%
# creating boxplots for features
plt.figure(figsize=(16,12))
plt.subplot(331)
sns.boxplot(df1.Age)
plt.subplot(332)
sns.boxplot(df1.Total_Bilirubin)
plt.subplot(333)
sns.boxplot(df1.Direct_Bilirubin)
plt.subplot(334)
sns.boxplot(df1.Alkaline_Phosphotase)
plt.subplot(335)
sns.boxplot(df1.Alamine_Aminotransferase)
plt.subplot(336)
sns.boxplot(df1.Aspartate_Aminotransferase)
plt.subplot(337)
sns.boxplot(df1.Total_Proteins)
plt.subplot(338)
sns.boxplot(df1.Albumin)
plt.subplot(339)
sns.boxplot(df1.Albumin_and_Globulin_Ratio);
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# removing outliers from certain features and printing len after outliers have been removed
print('Original dataset:',len(df1))
df1 = df1[df1.Total_Bilirubin < 40]
df1 = df1[df1.Direct_Bilirubin < 15.0]
df1 = df1[df1.Alkaline_Phosphotase < 1250]
df1 = df1[df1.Alamine_Aminotransferase < 1000]
df1 = df1[df1.Aspartate_Aminotransferase < 2000]
df1 = df1[df1.Albumin_and_Globulin_Ratio < 2.0]
print('After removing outliers:',len(df1))
# Out:
# Original dataset: 583
# After removing outliers: 560

# %%
# new dataframe shape
df1.shape
# Out:
# (560, 11)

# %%
# creating boxplots after removal of outliers
plt.figure(figsize=(16,12))
plt.subplot(331)
sns.boxplot(df1.Age)
plt.subplot(332)
sns.boxplot(df1.Total_Bilirubin)
plt.subplot(333)
sns.boxplot(df1.Direct_Bilirubin)
plt.subplot(334)
sns.boxplot(df1.Alkaline_Phosphotase)
plt.subplot(335)
sns.boxplot(df1.Alamine_Aminotransferase)
plt.subplot(336)
sns.boxplot(df1.Aspartate_Aminotransferase)
plt.subplot(337)
sns.boxplot(df1.Total_Proteins)
plt.subplot(338)
sns.boxplot(df1.Albumin)
plt.subplot(339)
sns.boxplot(df1.Albumin_and_Globulin_Ratio);
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# shapes of dataframes
print(df.shape)
print(df1.shape)
# Out:
# (583, 11)
# (560, 11)

# %% [markdown]
# # Log-transformation and min-max scaling (continuous features):

# %%
# distplot of age column
sns.distplot(df['Age'], hist = False, kde = True, color="purple",
                 kde_kws = {'shade': True, 'linewidth': 3});
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# distplot of total bilirubin column
sns.distplot(df['Total_Bilirubin'], hist = False, kde = True, color="green",
                 kde_kws = {'shade': True, 'linewidth': 3});
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# distplot of direct bilirubin column
sns.distplot(df['Direct_Bilirubin'], hist = False, kde = True, color="orange",
                 kde_kws = {'shade': True, 'linewidth': 3});
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# distplot of alkaline phosphotase column
sns.distplot(df['Alkaline_Phosphotase'], hist = False, kde = True, color="red",
                 kde_kws = {'shade': True, 'linewidth': 3});
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# distplot of alamine aminotransferase column
sns.distplot(df['Alamine_Aminotransferase'], hist = False, kde = True, color="black",
                 kde_kws = {'shade': True, 'linewidth': 3});
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# distplot of aspartate aminotransferase column
sns.distplot(df['Aspartate_Aminotransferase'], hist = False, kde = True, color="purple",
                 kde_kws = {'shade': True, 'linewidth': 3});
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# distlot of total proteins column
sns.distplot(df['Total_Proteins'], hist = False, kde = True, color="green",
                 kde_kws = {'shade': True, 'linewidth': 3});
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# distplot of albumin column 
sns.distplot(df['Albumin'], hist = False, kde = True, color="orange",
                 kde_kws = {'shade': True, 'linewidth': 3});
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# distplot of albumin and globulin ratio column
sns.distplot(df['Albumin_and_Globulin_Ratio'], hist = False, kde = True, color="red",
                 kde_kws = {'shade': True, 'linewidth': 3});
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# creating a distplot of all features in one plot
plt.figure(figsize=(16,4))
plt.subplot(121)
sns.distplot(df1.Total_Bilirubin, label='total_bilirubin')
sns.distplot(df1.Direct_Bilirubin, label='direct_bilirubin')
sns.distplot(df1.Alkaline_Phosphotase, label='alkaline_phosphotase')
sns.distplot(df1.Alamine_Aminotransferase, label='alamine_aminotransferase')
sns.distplot(df1.Aspartate_Aminotransferase, label='aspartate_aminotransferase')
sns.distplot(df1.Total_Proteins, label='total_proteins')
sns.distplot(df1.Albumin, label='albumin')
sns.distplot(df1.Albumin_and_Globulin_Ratio, label='albumin_and_globulin_ratio')


plt.title('Original Features', fontdict={'fontsize': 20})
plt.xlabel('Features')
plt.legend()

# creating a zoomed-in representation of the same distplot showing all features
plt.subplot(122)
sns.distplot(df1.Total_Bilirubin, label='total_bilirubin')
sns.distplot(df1.Direct_Bilirubin, label='direct_bilirubin')
sns.distplot(df1.Alkaline_Phosphotase, label='alkaline_phosphotase')
sns.distplot(df1.Alamine_Aminotransferase, label='alamine_aminotransferase')
sns.distplot(df1.Aspartate_Aminotransferase, label='aspartate_aminotransferase')
sns.distplot(df1.Total_Proteins, label='total_proteins')
sns.distplot(df1.Albumin, label='albumin')
sns.distplot(df1.Albumin_and_Globulin_Ratio, label='albumin_and_globulin_ratio')
plt.title('Original Features (Zoomed in)', fontdict={'fontsize': 20})
plt.xlabel('Features')
plt.xlim(0, 10)
plt.legend()
plt.show()
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# creating log transformation of all features and creating new distplot
Total_Bilirubin = np.log(df1.Total_Bilirubin)
Direct_Bilirubin = np.log(df1.Direct_Bilirubin)
Alkaline_Phosphotase = np.log(df1.Alkaline_Phosphotase)
Alamine_Aminotransferase = np.log(df1.Alamine_Aminotransferase)
Aspartate_Aminotransferase = np.log(df1.Aspartate_Aminotransferase)
Total_Proteins = np.log(df1.Total_Proteins)
Albumin = np.log(df1.Albumin)
Albumin_and_Globulin_Ratio = np.log(df1.Albumin_and_Globulin_Ratio)

plt.figure(figsize=(7.5,4))
sns.distplot(Total_Bilirubin, label='total_bilirubin')
sns.distplot(Direct_Bilirubin, label='direct_bilirubin')
sns.distplot(Alkaline_Phosphotase, label='alkaline_phosphotase')
sns.distplot(Alamine_Aminotransferase, label='alamine_aminotransferase')
sns.distplot(Aspartate_Aminotransferase, label='aspartate_aminotransferase')
sns.distplot(Total_Proteins, label='total_proteins')
sns.distplot(Albumin, label='albumin')
sns.distplot(Albumin_and_Globulin_Ratio, label='albumin_and_globulin_ratio')

plt.title('Log Transformed Features', fontdict={'fontsize': 20})
plt.xlabel('Features')
plt.legend()
plt.show()
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# min-max scaling by-hand all the features and creating new distplot 
df1['Total_Bilirubin'] = ( Total_Bilirubin - min(Total_Bilirubin) ) / ( max(Total_Bilirubin) - min(Total_Bilirubin) )
df1['Direct_Bilirubin'] = ( Direct_Bilirubin - min(Direct_Bilirubin) ) / ( max(Direct_Bilirubin) - min(Direct_Bilirubin) )
df1['Alkaline_Phosphotase'] = ( Alkaline_Phosphotase - min(Alkaline_Phosphotase) ) / ( max(Alkaline_Phosphotase) - min(Alkaline_Phosphotase) )
df1['Alamine_Aminotransferase'] = ( Alamine_Aminotransferase - min(Alamine_Aminotransferase) ) / ( max(Alamine_Aminotransferase) - min(Alamine_Aminotransferase) )
df1['Aspartate_Aminotransferase'] = ( Aspartate_Aminotransferase - min(Aspartate_Aminotransferase) ) / ( max(Aspartate_Aminotransferase) - min(Aspartate_Aminotransferase) )
df1['Total_Proteins'] = ( Total_Proteins - min(Total_Proteins) ) / ( max(Total_Proteins) - min(Total_Proteins) )
df1['Albumin'] = ( Albumin - min(Albumin) ) / ( max(Albumin) - min(Albumin) )
df1['Albumin_and_Globulin_Ratio'] = ( Albumin_and_Globulin_Ratio - min(Albumin_and_Globulin_Ratio) ) / ( max(Albumin_and_Globulin_Ratio) - min(Albumin_and_Globulin_Ratio) )



plt.figure(figsize=(7.5,4))
sns.distplot(df1.Total_Bilirubin, label='total_bilirubin')
sns.distplot(df1.Direct_Bilirubin, label='direct_bilirubin')
sns.distplot(df1.Alkaline_Phosphotase, label='alkaline_phosphotase')
sns.distplot(df1.Alamine_Aminotransferase, label='alamine_aminotransferase')
sns.distplot(df1.Aspartate_Aminotransferase, label='aspartate_aminotransferase')
sns.distplot(df1.Total_Proteins, label='total_proteins')
sns.distplot(df1.Albumin, label='albumin')
sns.distplot(df1.Albumin_and_Globulin_Ratio, label='albumin_and_globulin_ratio')


plt.title('Scaled Features', fontdict={'fontsize': 20})
plt.xlabel('Features')
plt.legend()
plt.show()
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# new distplot of total bilirubin
sns.distplot(df1['Total_Bilirubin'], hist = False, kde = True, color="green",
                 kde_kws = {'shade': True, 'linewidth': 3});
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# new distplot of direct bilirubin
sns.distplot(df1['Direct_Bilirubin'], hist = False, kde = True, color="orange",
                 kde_kws = {'shade': True, 'linewidth': 3});
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# new distplot of alkaline phosphotase
sns.distplot(df1['Alkaline_Phosphotase'], hist = False, kde = True, color="red",
                 kde_kws = {'shade': True, 'linewidth': 3});
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# new distplot of alamine aminotransferase
sns.distplot(df1['Alamine_Aminotransferase'], hist = False, kde = True, color="black",
                 kde_kws = {'shade': True, 'linewidth': 3});
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# new distplot of aspartate aminotransferase
sns.distplot(df1['Aspartate_Aminotransferase'], hist = False, kde = True, color="purple",
                 kde_kws = {'shade': True, 'linewidth': 3});
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# new distplot of total proteins
sns.distplot(df1['Total_Proteins'], hist = False, kde = True, color="green",
                 kde_kws = {'shade': True, 'linewidth': 3});
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# new distplot of albumin
sns.distplot(df1['Albumin'], hist = False, kde = True, color="orange",
                 kde_kws = {'shade': True, 'linewidth': 3});
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# new distplot of albumin and globulin ratio
sns.distplot(df1['Albumin_and_Globulin_Ratio'], hist = False, kde = True, color="red",
                 kde_kws = {'shade': True, 'linewidth': 3});
# Out:
# C:\Users\DELL\anaconda4\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Binning of age column (discrete categorical feature):

# %%
# retrieving age unique values
df1['Age'].unique()
# Out:
# array([65, 62, 58, 72, 46, 26, 29, 17, 55, 57, 64, 74, 61, 25, 38, 33, 40,
#        51, 63, 34, 20, 84, 52, 30, 48, 47, 45, 42, 50, 85, 35, 21, 32, 31,
#        54, 37, 66, 60, 19, 75, 68, 70, 49, 14, 13, 18, 39, 27, 36, 24, 28,
#        53, 15, 56, 44, 41, 22,  8,  6,  4, 43, 23, 12, 69, 16, 78, 11,  7,
#        67, 10, 73, 90], dtype=int64)

# %%
# retrieving max unique value for age
df1['Age'].unique().max()
# Out:
# 90

# %%
# binning age column and replacing values in terms of age group 1 = youth, 2 = adult, and 3 = elderly
# youth = 0-23, adult = 24-63, elderly = 64-99 
# max age was 90
df1['Age'] = pd.cut(df1['Age'], bins=[0,24,64,100], labels=[1,2,3])

# %%
# retrieving age value counts
df1['Age'].value_counts()
# Out:
# 2    422
# 3     74
# 1     64
# Name: Age, dtype: int64

# %%
# percent of people tested that are adults
adult_count = (df1['Age'] == 2).sum()
total_count = len(df1['Age'])

percent_adults = (adult_count/total_count)*100

print('From all the people that were tested, {:.2f}% are adults'.format(percent_adults))
# Out:
# From all the people that were tested, 75.36% are adults

# %%
# retrieving dataframe shape
df1.shape
# Out:
# (560, 11)

# %%
# value counts of liver disease in terms of age group
df1.groupby('Liver_Disease')['Age'].value_counts()
# Out:
# Liver_Disease
# 0              2    305
#                3     56
#                1     33
# 1              2    117
#                1     31
#                3     18
# Name: Age, dtype: int64

# %%
print('Percent of people with liver disease that are in the adult age group of 24-63 years of age is {:.2f}%'
      .format((117/(117+31+18)) *100))
# Out:
# Percent of people with liver disease that are in the adult age group of 24-63 years of age is 70.48%

# %% [markdown]
# One-hot encoding (discrete categorical features):

# %%
# creating dummies for dataset
df1 = pd.get_dummies(df1)

# %%
# retrieving shape of dataset
df1.shape
# Out:
# (560, 14)

# %%
# retrieving dataframe column list
df1.columns.tolist()
# Out:
# ['Total_Bilirubin',
#  'Direct_Bilirubin',
#  'Alkaline_Phosphotase',
#  'Alamine_Aminotransferase',
#  'Aspartate_Aminotransferase',
#  'Total_Proteins',
#  'Albumin',
#  'Albumin_and_Globulin_Ratio',
#  'Liver_Disease',
#  'Age_1',
#  'Age_2',
#  'Age_3',
#  'Gender_Female',
#  'Gender_Male']

# %% [markdown]
# # Final Dataset:

# %%
# dataframe iloc
df1.iloc[0]
# Out:
# Total_Bilirubin               0.127168
# Direct_Bilirubin              0.000000
# Alkaline_Phosphotase          0.377570
# Alamine_Aminotransferase      0.103210
# Aspartate_Aminotransferase    0.117308
# Total_Proteins                0.728153
# Albumin                       0.717793
# Albumin_and_Globulin_Ratio    0.595187
# Liver_Disease                 0.000000
# Age_1                         0.000000
# Age_2                         0.000000
# Age_3                         1.000000
# Gender_Female                 1.000000
# Gender_Male                   0.000000
# Name: 0, dtype: float64

# %%
# dataframe iloc
df1.iloc[-1]
# Out:
# Total_Bilirubin               0.208219
# Direct_Bilirubin              0.221681
# Alkaline_Phosphotase          0.427603
# Alamine_Aminotransferase      0.162924
# Aspartate_Aminotransferase    0.174722
# Total_Proteins                0.784086
# Albumin                       0.876724
# Albumin_and_Globulin_Ratio    0.871933
# Liver_Disease                 1.000000
# Age_1                         0.000000
# Age_2                         1.000000
# Age_3                         0.000000
# Gender_Female                 0.000000
# Gender_Male                   1.000000
# Name: 582, dtype: float64

# %%
# retrieving dataframe information
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 560 entries, 0 to 582
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Total_Bilirubin             560 non-null    float64
#  1   Direct_Bilirubin            560 non-null    float64
#  2   Alkaline_Phosphotase        560 non-null    float64
#  3   Alamine_Aminotransferase    560 non-null    float64
#  4   Aspartate_Aminotransferase  560 non-null    float64
#  5   Total_Proteins              560 non-null    float64
#  6   Albumin                     560 non-null    float64
#  7   Albumin_and_Globulin_Ratio  560 non-null    float64
#  8   Liver_Disease               560 non-null    int64
#  9   Age_1                       560 non-null    uint8
#  10  Age_2                       560 non-null    uint8
#  11  Age_3                       560 non-null    uint8
#  12  Gender_Female               560 non-null    uint8
#  13  Gender_Male                 560 non-null    uint8
# dtypes: float64(8), int64(1), uint8(5)
# memory usage: 46.5 KB

# %%
# retrieving dataframe description
df1.describe()
# Out:
#        Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count       560.000000        560.000000            560.000000
# mean          0.297659          0.317686              0.455325
# std           0.213661          0.253829              0.161947
# min           0.000000          0.000000              0.000000
# 25%           0.157512          0.139865              0.354554
# 50%           0.208219          0.221681              0.410308
# 75%           0.397491          0.488243              0.529842
# max           1.000000          1.000000              1.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Proteins  \
# count                560.000000                  560.000000      560.000000
# mean                   0.305595                    0.317323        0.679252
# std                    0.180041                    0.184880        0.142197
# min                    0.000000                    0.000000        0.000000
# 25%                    0.182901                    0.182869        0.602759
# 50%                    0.262177                    0.276670        0.704620
# 75%                    0.386952                    0.415006        0.773213
# max                    1.000000                    1.000000        1.000000
#
#           Albumin  Albumin_and_Globulin_Ratio  Liver_Disease       Age_1  \
# count  560.000000                  560.000000     560.000000  560.000000
# mean     0.673549                    0.592909       0.296429    0.114286
# std      0.153810                    0.180981       0.457091    0.318442
# min      0.000000                    0.000000       0.000000    0.000000
# 25%      0.586082                    0.464798       0.000000    0.000000
# 50%      0.683253                    0.627315       0.000000    0.000000
# 75%      0.795732                    0.703903       1.000000    0.000000
# max      1.000000                    1.000000       1.000000    1.000000
#
#             Age_2       Age_3  Gender_Female  Gender_Male
# count  560.000000  560.000000     560.000000   560.000000
# mean     0.753571    0.132143       0.242857     0.757143
# std      0.431316    0.338949       0.429193     0.429193
# min      0.000000    0.000000       0.000000     0.000000
# 25%      1.000000    0.000000       0.000000     1.000000
# 50%      1.000000    0.000000       0.000000     1.000000
# 75%      1.000000    0.000000       0.000000     1.000000
# max      1.000000    1.000000       1.000000     1.000000

# %% [markdown]
# # Pairplot

# %%
# creating dataframe pairplot
sns.pairplot(df1);

# %% [markdown]
# Creating machine learning-ready-dataset:

# %%
# creating dataframe copy and assigning it to new dataframe variable to be used in machine learning section
liver_final = df1.copy()

# %%
# retrieving dataframe shape
liver_final.shape
# Out:
# (560, 14)

# %%
# retrieving dataframe information
liver_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 560 entries, 0 to 582
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Total_Bilirubin             560 non-null    float64
#  1   Direct_Bilirubin            560 non-null    float64
#  2   Alkaline_Phosphotase        560 non-null    float64
#  3   Alamine_Aminotransferase    560 non-null    float64
#  4   Aspartate_Aminotransferase  560 non-null    float64
#  5   Total_Proteins              560 non-null    float64
#  6   Albumin                     560 non-null    float64
#  7   Albumin_and_Globulin_Ratio  560 non-null    float64
#  8   Liver_Disease               560 non-null    int64
#  9   Age_1                       560 non-null    uint8
#  10  Age_2                       560 non-null    uint8
#  11  Age_3                       560 non-null    uint8
#  12  Gender_Female               560 non-null    uint8
#  13  Gender_Male                 560 non-null    uint8
# dtypes: float64(8), int64(1), uint8(5)
# memory usage: 62.6 KB

# %%
# retrieving dataframe description
liver_final.describe()
# Out:
#        Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count       560.000000        560.000000            560.000000
# mean          0.297659          0.317686              0.455325
# std           0.213661          0.253829              0.161947
# min           0.000000          0.000000              0.000000
# 25%           0.157512          0.139865              0.354554
# 50%           0.208219          0.221681              0.410308
# 75%           0.397491          0.488243              0.529842
# max           1.000000          1.000000              1.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Proteins  \
# count                560.000000                  560.000000      560.000000
# mean                   0.305595                    0.317323        0.679252
# std                    0.180041                    0.184880        0.142197
# min                    0.000000                    0.000000        0.000000
# 25%                    0.182901                    0.182869        0.602759
# 50%                    0.262177                    0.276670        0.704620
# 75%                    0.386952                    0.415006        0.773213
# max                    1.000000                    1.000000        1.000000
#
#           Albumin  Albumin_and_Globulin_Ratio  Liver_Disease       Age_1  \
# count  560.000000                  560.000000     560.000000  560.000000
# mean     0.673549                    0.592909       0.296429    0.114286
# std      0.153810                    0.180981       0.457091    0.318442
# min      0.000000                    0.000000       0.000000    0.000000
# 25%      0.586082                    0.464798       0.000000    0.000000
# 50%      0.683253                    0.627315       0.000000    0.000000
# 75%      0.795732                    0.703903       1.000000    0.000000
# max      1.000000                    1.000000       1.000000    1.000000
#
#             Age_2       Age_3  Gender_Female  Gender_Male
# count  560.000000  560.000000     560.000000   560.000000
# mean     0.753571    0.132143       0.242857     0.757143
# std      0.431316    0.338949       0.429193     0.429193
# min      0.000000    0.000000       0.000000     0.000000
# 25%      1.000000    0.000000       0.000000     1.000000
# 50%      1.000000    0.000000       0.000000     1.000000
# 75%      1.000000    0.000000       0.000000     1.000000
# max      1.000000    1.000000       1.000000     1.000000

# %%
# retrieving dataframe column list 
liver_final.columns.tolist()
# Out:
# ['Total_Bilirubin',
#  'Direct_Bilirubin',
#  'Alkaline_Phosphotase',
#  'Alamine_Aminotransferase',
#  'Aspartate_Aminotransferase',
#  'Total_Proteins',
#  'Albumin',
#  'Albumin_and_Globulin_Ratio',
#  'Liver_Disease',
#  'Age_1',
#  'Age_2',
#  'Age_3',
#  'Gender_Female',
#  'Gender_Male']

# %%
# retrieving len of dataframe
len(liver_final)
# Out:
# 560

# %%
# retrieving correlations of dataframe
liver_final.corr()
# Out:
#                             Total_Bilirubin  Direct_Bilirubin  \
# Total_Bilirubin                    1.000000          0.966698
# Direct_Bilirubin                   0.966698          1.000000
# Alkaline_Phosphotase               0.356621          0.355773
# Alamine_Aminotransferase           0.417990          0.405065
# Aspartate_Aminotransferase         0.520560          0.509486
# Total_Proteins                    -0.060583         -0.045429
# Albumin                           -0.288661         -0.269585
# Albumin_and_Globulin_Ratio        -0.390766         -0.376063
# Liver_Disease                     -0.305825         -0.305773
# Age_1                             -0.109039         -0.116840
# Age_2                              0.088056          0.101176
# Age_3                             -0.009610         -0.018976
# Gender_Female                     -0.190366         -0.207725
# Gender_Male                        0.190366          0.207725
#
#                             Alkaline_Phosphotase  Alamine_Aminotransferase  \
# Total_Bilirubin                         0.356621                  0.417990
# Direct_Bilirubin                        0.355773                  0.405065
# Alkaline_Phosphotase                    1.000000                  0.333151
# Alamine_Aminotransferase                0.333151                  1.000000
# Aspartate_Aminotransferase              0.294401                  0.812991
# Total_Proteins                          0.014309                  0.010004
# Albumin                                -0.133452                 -0.015757
# Albumin_and_Globulin_Ratio             -0.269491                 -0.064389
# Liver_Disease                          -0.233867                 -0.282942
# Age_1                                   0.070966                  0.005163
# Age_2                                  -0.054418                  0.092642
# Age_3                                   0.002575                 -0.122739
# Gender_Female                          -0.073269                 -0.181459
# Gender_Male                             0.073269                  0.181459
#
#                             Aspartate_Aminotransferase  Total_Proteins  \
# Total_Bilirubin                               0.520560       -0.060583
# Direct_Bilirubin                              0.509486       -0.045429
# Alkaline_Phosphotase                          0.294401        0.014309
# Alamine_Aminotransferase                      0.812991        0.010004
# Aspartate_Aminotransferase                    1.000000       -0.046730
# Total_Proteins                               -0.046730        1.000000
# Albumin                                      -0.158345        0.798439
# Albumin_and_Globulin_Ratio                   -0.207412        0.267547
# Liver_Disease                                -0.290358        0.037381
# Age_1                                        -0.003827        0.118075
# Age_2                                         0.064559        0.048891
# Age_3                                        -0.078556       -0.173146
# Gender_Female                                -0.196281        0.078974
# Gender_Male                                   0.196281       -0.078974
#
#                              Albumin  Albumin_and_Globulin_Ratio  \
# Total_Bilirubin            -0.288661                   -0.390766
# Direct_Bilirubin           -0.269585                   -0.376063
# Alkaline_Phosphotase       -0.133452                   -0.269491
# Alamine_Aminotransferase   -0.015757                   -0.064389
# Aspartate_Aminotransferase -0.158345                   -0.207412
# Total_Proteins              0.798439                    0.267547
# Albumin                     1.000000                    0.769408
# Albumin_and_Globulin_Ratio  0.769408                    1.000000
# Liver_Disease               0.150378                    0.196580
# Age_1                       0.173902                    0.157868
# Age_2                       0.020222                   -0.002443
# Age_3                      -0.189113                   -0.145209
# Gender_Female               0.086730                    0.040575
# Gender_Male                -0.086730                   -0.040575
#
#                             Liver_Disease     Age_1     Age_2     Age_3  \
# Total_Bilirubin                 -0.305825 -0.109039  0.088056 -0.009610
# Direct_Bilirubin                -0.305773 -0.116840  0.101176 -0.018976
# Alkaline_Phosphotase            -0.233867  0.070966 -0.054418  0.002575
# Alamine_Aminotransferase        -0.282942  0.005163  0.092642 -0.122739
# Aspartate_Aminotransferase      -0.290358 -0.003827  0.064559 -0.078556
# Total_Proteins                   0.037381  0.118075  0.048891 -0.173146
# Albumin                          0.150378  0.173902  0.020222 -0.189113
# Albumin_and_Globulin_Ratio       0.196580  0.157868 -0.002443 -0.145209
# Liver_Disease                    1.000000  0.147832 -0.073433 -0.045444
# Age_1                            0.147832  1.000000 -0.628154 -0.140167
# Age_2                           -0.073433 -0.628154  1.000000 -0.682361
# Age_3                           -0.045444 -0.140167 -0.682361  1.000000
# Gender_Female                    0.088321  0.019072 -0.004694 -0.011946
# Gender_Male                     -0.088321 -0.019072  0.004694  0.011946
#
#                             Gender_Female  Gender_Male
# Total_Bilirubin                 -0.190366     0.190366
# Direct_Bilirubin                -0.207725     0.207725
# Alkaline_Phosphotase            -0.073269     0.073269
# Alamine_Aminotransferase        -0.181459     0.181459
# Aspartate_Aminotransferase      -0.196281     0.196281
# Total_Proteins                   0.078974    -0.078974
# Albumin                          0.086730    -0.086730
# Albumin_and_Globulin_Ratio       0.040575    -0.040575
# Liver_Disease                    0.088321    -0.088321
# Age_1                            0.019072    -0.019072
# Age_2                           -0.004694     0.004694
# Age_3                           -0.011946     0.011946
# Gender_Female                    1.000000    -1.000000
# Gender_Male                     -1.000000     1.000000

# %%
# final copy 
liver_final = df1.copy()

# %% [markdown]
# # Machine Learning Algorithms

# %%
# importing machine learning libraries and modules
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.ensemble import AdaBoostClassifier, RandomForestRegressor
from pprint import pprint
from sklearn.metrics import mean_squared_error, precision_score, recall_score, accuracy_score, f1_score, roc_curve, auc, confusion_matrix, classification_report, roc_auc_score
import warnings
import xgboost as xgb
from sklearn.tree import DecisionTreeClassifier
from pprint import pprint
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from time import time
import scipy.stats as stats 
import scipy.stats
from sklearn.linear_model import SGDClassifier
warnings.filterwarnings('ignore')

# %%
# creating print_metrics function
def print_metrics(labels, preds):
    print("Precision Score: {}".format(precision_score(labels, preds)))
    print("Recall Score: {}".format(recall_score(labels, preds)))
    print("Accuracy Score: {}".format(accuracy_score(labels, preds)))
    print("F1 Score: {}".format(f1_score(labels, preds)))

# %% [markdown]
# # Test-train split:

# %%
# creating train_test_split and retrieving shapes of each
X = liver_final.drop(['Liver_Disease'], axis=1)
y = liver_final['Liver_Disease']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print('X_train shape: {}'.format(X_train.shape))
print('X_test shape {}'.format(X_test.shape))
print('y_train shape {}'.format(y_train.shape))
print('y_test shape {}'.format(y_test.shape))
# Out:
# X_train shape: (392, 13)
# X_test shape (168, 13)
# y_train shape (392,)
# y_test shape (168,)

# %% [markdown]
# # Support Vector Machines (SVM) Algorithm:

# %%
# making copy
liver_final = df1.copy()

# %%
# creating train_test_splot
X = liver_final.drop(['Liver_Disease'], axis=1)
y = liver_final['Liver_Disease']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# instantiating, fitting, and predicting using SVM algorithm model
svm_clf = svm.SVC(random_state=42)

svm_clf.fit(X_train, y_train)

svm_y_trials = svm_clf.predict(X_train)

svm_y_pred = svm_clf.predict(X_test)

# %%
# showing metrics for testing set
print('SVM Test Metrics:')
print_metrics(y_test, svm_y_pred)
# Out:
# SVM Test Metrics:
# Precision Score: 0.4090909090909091
# Recall Score: 0.225
# Accuracy Score: 0.7380952380952381
# F1 Score: 0.2903225806451613

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Assuming you have the true labels in y_test and predicted labels in svm_y_pred
confusion_mat = confusion_matrix(y_test, svm_y_pred)

# Create a heatmap using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='Blues')

# Set labels, title, and ticks
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('SVM Confusion Matrix')

# Show the plot
plt.show()

# %%
# showing auc of SVM algorithm
print('SVM AUC:')
svm_false_positive_rate, svm_true_positive_rate, svm_thresholds = roc_curve(y_test, svm_y_pred)
svm_auc = auc(svm_false_positive_rate, svm_true_positive_rate)
svm_auc
# Out:
# SVM AUC:
# 0.56171875

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Assuming you have the true labels in y_test and predicted labels in svm_y_pred
svm_false_positive_rate, svm_true_positive_rate, svm_thresholds = roc_curve(y_test, svm_y_pred)
svm_auc = auc(svm_false_positive_rate, svm_true_positive_rate)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(svm_false_positive_rate, svm_true_positive_rate, label='SVM (AUC = %0.2f)' % svm_auc)
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# Print AUC
print('SVM AUC:', svm_auc)
# Out:
# SVM AUC: 0.56171875

# %% [markdown]
# # K-Nearest Neighbors Algorithm:

# %%
# making copy
liver_final = df1.copy()

# %%
# creating train_test_split
X = liver_final.drop(['Liver_Disease'], axis=1)
y = liver_final['Liver_Disease']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# instantiating, fitting, and predicting using KNN algorithm model
knn_clf = KNeighborsClassifier()

knn_clf.fit(X_train, y_train)

knn_y_trials = knn_clf.predict(X_train)

knn_y_pred = knn_clf.predict(X_test)

# %%
# showing metrics for for test set
print('KNN Test Metrics:')
print('\n')
print_metrics(y_test, knn_y_pred)
# Out:
# KNN Test Metrics:
#
#
# Precision Score: 0.4222222222222222
# Recall Score: 0.475
# Accuracy Score: 0.7202380952380952
# F1 Score: 0.4470588235294118

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Assuming you have the true labels in y_test and predicted labels in knn_y_pred
confusion_mat = confusion_matrix(y_test, knn_y_pred)

# Create a heatmap using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='Blues')

# Set labels, title, and ticks
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('KNN Confusion Matrix')

# Show the plot
plt.show()

# %%
# showing auc of KNN algorithm
print('KNN AUC:')
knn_false_positive_rate, knn_true_positive_rate, knn_thesholds = roc_curve(y_test, knn_y_pred)
knn_auc = auc(knn_false_positive_rate, knn_true_positive_rate)
knn_auc
# Out:
# KNN AUC:
# 0.6359375

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Assuming you have the true labels in y_test and predicted labels in knn_y_pred
knn_false_positive_rate, knn_true_positive_rate, knn_thresholds = roc_curve(y_test, knn_y_pred)
knn_auc = auc(knn_false_positive_rate, knn_true_positive_rate)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(knn_false_positive_rate, knn_true_positive_rate, label='KNN (AUC = %0.2f)' % knn_auc)
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# Print AUC
print('KNN AUC:', knn_auc)
# Out:
# KNN AUC: 0.6359375

# %% [markdown]
# # Decision Tree Algorithm:

# %%
# making copy
liver_final = df1.copy()

# %%
# creating train_test_split
X = liver_final.drop(['Liver_Disease'], axis=1)
y = liver_final['Liver_Disease']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# instantiating, fitting, and predicting using Decision Tree algorithm model
dt_clf = DecisionTreeClassifier(random_state=42)

dt_clf.fit(X_train, y_train)

dt_y_trails = dt_clf.predict(X_train)

dt_y_pred = dt_clf.predict(X_test)

# %%
# showing metrics for test sets
print('Decision Tree Test Metrics:')
print('\n')
print_metrics(y_test, dt_y_pred)
# Out:
# Decision Tree Test Metrics:
#
#
# Precision Score: 0.34615384615384615
# Recall Score: 0.45
# Accuracy Score: 0.6666666666666666
# F1 Score: 0.3913043478260869

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Assuming you have the true labels in y_test and predicted labels in dt_y_pred
confusion_mat = confusion_matrix(y_test, dt_y_pred)

# Create a heatmap using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='BuPu')

# Set labels, title, and ticks
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Decision Tree Confusion Matrix')

# Show the plot
plt.show()

# %%
# showing auc of Decision Tree algorithm
print('Decision Tree AUC:')
dt_false_positive_rate, dt_true_positive_rate, dt_thesholds = roc_curve(y_test, dt_y_pred)
dt_auc = auc(dt_false_positive_rate, dt_true_positive_rate)
dt_auc
# Out:
# Decision Tree AUC:
# 0.5921875

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Assuming you have the true labels in y_test and predicted labels in dt_y_pred
dt_false_positive_rate, dt_true_positive_rate, dt_thresholds = roc_curve(y_test, dt_y_pred)
dt_auc = auc(dt_false_positive_rate, dt_true_positive_rate)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(dt_false_positive_rate, dt_true_positive_rate, label='Decision Tree (AUC = %0.2f)' % dt_auc)
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# Print AUC
print('Decision Tree AUC:', dt_auc)
# Out:
# Decision Tree AUC: 0.5921875

# %% [markdown]
# # Random Forest Algorithm:

# %%
# making copy
liver_final = df1.copy()

# %%
# creating train_test_split
X = liver_final.drop(['Liver_Disease'], axis=1)
y = liver_final['Liver_Disease']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# instantiating, fitting, and predicting using Random Forest algorithm model
rf_clf = RandomForestClassifier(random_state=42)

rf_clf.fit(X_train, y_train)

rf_y_trials = rf_clf.predict(X_train)

rf_y_pred = rf_clf.predict(X_test)

# %%
# showing metrics for test set
print('Random Forest Test Metrics:')
print('\n')
print_metrics(y_test, rf_y_pred)
# Out:
# Random Forest Test Metrics:
#
#
# Precision Score: 0.47058823529411764
# Recall Score: 0.4
# Accuracy Score: 0.75
# F1 Score: 0.4324324324324324

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Assuming you have the true labels in y_test and predicted labels in rf_y_pred
confusion_mat = confusion_matrix(y_test, rf_y_pred)

# Create a heatmap using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='PRGn_r')

# Set labels, title, and ticks
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Random Forest Confusion Matrix')

# Show the plot
plt.show()

# %%
# showing auc of Random Forest algorithm
print('Random Forest AUC:')
rf_false_positive_rate, rf_true_positive_rate, rf_thesholds = roc_curve(y_test, rf_y_pred)
rf_auc = auc(rf_false_positive_rate, rf_true_positive_rate)
rf_auc
# Out:
# Random Forest AUC:
# 0.6296875

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Assuming you have the true labels in y_test and predicted labels in rf_y_pred
rf_false_positive_rate, rf_true_positive_rate, rf_thresholds = roc_curve(y_test, rf_y_pred)
rf_auc = auc(rf_false_positive_rate, rf_true_positive_rate)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(rf_false_positive_rate, rf_true_positive_rate, label='Random Forest (AUC = %0.2f)' % rf_auc)
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# Print AUC
print('Random Forest AUC:', rf_auc)
# Out:
# Random Forest AUC: 0.6296875

# %% [markdown]
# # LSTM

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# making copy
liver_final = df1.copy()

# Separate features and target
X = df.drop('Liver_Disease', axis=1)
y = df['Liver_Disease']

# Perform necessary data cleaning and exploration steps here

# Perform one-hot encoding for categorical variables
categorical_columns = ['Gender']
X_encoded = pd.get_dummies(X, columns=categorical_columns)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Scale the features using MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = Sequential()
model.add(LSTM(units=64, input_shape=(X_train.shape[1], 1)))
model.add(Dense(units=1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Print the summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 16,961
# Trainable params: 16,961
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=5, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/5
# 15/15 [==============================] - 5s 74ms/step - loss: 0.6547 - accuracy: 0.6245 - val_loss: 0.5767 - val_accuracy: 0.7436
# Epoch 2/5
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6079 - accuracy: 0.7060 - val_loss: 0.5778 - val_accuracy: 0.7436
# Epoch 3/5
# 15/15 [==============================] - 0s 8ms/step - loss: 0.6059 - accuracy: 0.7060 - val_loss: 0.5650 - val_accuracy: 0.7436
# Epoch 4/5
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6013 - accuracy: 0.7060 - val_loss: 0.5516 - val_accuracy: 0.7436
# Epoch 5/5
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5867 - accuracy: 0.7060 - val_loss: 0.5345 - val_accuracy: 0.7436

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
# Out:
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5345 - accuracy: 0.7436
# Test Loss: 0.5344827771186829
# Test Accuracy: 0.7435897588729858

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score

# Assuming you have already trained the LSTM model and obtained predictions
y_pred_probs = model.predict(X_test)
y_pred = (y_pred_probs > 0.5).astype(int).flatten()  # Flattening predictions if necessary

# Convert y_test to a NumPy array if needed
y_test = np.array(y_test)

# Check if there are any positive predictions
if np.sum(y_pred) == 0:
    print("Warning: No positive predictions were made.")

# Calculate precision, recall, and F1-score
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Print the metrics
print('Precision:', precision)
print('Recall:', recall)
print('F1-score:', f1)
# Out:
# Warning: No positive predictions were made.
# Precision: 0.0
# Recall: 0.0
# F1-score: 0.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Assuming you have already trained the LSTM model and obtained predictions
y_pred_probs = model.predict(X_test)
y_pred = (y_pred_probs > 0.5).astype(int)

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Assuming you have the true labels in y_test and predicted probabilities in y_pred_probs
lstm_false_positive_rate, lstm_true_positive_rate, lstm_thresholds = roc_curve(y_test, y_pred_probs)
lstm_auc = auc(lstm_false_positive_rate, lstm_true_positive_rate)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(lstm_false_positive_rate, lstm_true_positive_rate, label='LSTM (AUC = %0.2f)' % lstm_auc)
plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# Print AUC
print('LSTM AUC:', lstm_auc)
# Out:
# LSTM AUC: 0.7766283524904214

# %%
# creating no skill line
ns_probs = [0 for _ in range(len(y_test))]
ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)

plt.figure(figsize=(20,15))
plt.title('ROC/AUC Curves',fontsize=30)
# plot the roc curve for the model
plt.plot(ns_fpr, ns_tpr, color='black', linestyle='--', label='No Skill')
plt.plot(svm_false_positive_rate, svm_true_positive_rate, color='red', linestyle='-', marker='.', label='SVM (auc = %0.7f)' % svm_auc)
plt.plot(knn_false_positive_rate, knn_true_positive_rate, color='green', linestyle='-', marker='*', label='KNN (auc = %0.7f)' % knn_auc)
plt.plot(dt_false_positive_rate, dt_true_positive_rate, color='limegreen', linestyle='-', marker='+', label='Decision Tree (auc = %0.7f)' % dt_auc)
plt.plot(rf_false_positive_rate, rf_true_positive_rate, color='orange', linestyle='-', marker='.', label='Random Forest (auc = %0.8f)' % rf_auc)
plt.plot(lstm_false_positive_rate, lstm_true_positive_rate, color='purple', linestyle='-', marker='*', label='LSTM (auc = %0.7f)' % lstm_auc)


# axis labels
plt.xlabel('False Positive Rate', fontsize=20)
plt.ylabel('True Positive Rate', fontsize=20)

# show the legend
plt.legend(prop={'size': 20})


# show the plot
plt.show()

# %% [markdown]
# # Random Forest Algorithm + Hyperparameter Optimization:

# %%
# making copy
liver_final = df1.copy()
# creating train_test_split
X = liver_final.drop(['Liver_Disease'], axis=1)
y = liver_final['Liver_Disease']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# instantiating model
forest = RandomForestClassifier(random_state = 42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_curve, auc
import pandas as pd
import numpy as np

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score

# Load the dataset
liver_final = df1.copy()

# Split the data into features and target
X = liver_final.drop(['Liver_Disease'], axis=1)
y = liver_final['Liver_Disease']

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define the parameter grid for GridSearchCV
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
}

# Instantiate the Random Forest classifier
rf_clf = RandomForestClassifier(random_state=42)

# Perform grid search to find the best hyperparameters
grid_search = GridSearchCV(rf_clf, param_grid, cv=5)
grid_search.fit(X_train, y_train)

# Get the best estimator from the grid search
best_rf_clf = grid_search.best_estimator_

# Fit the best model on the training data
best_rf_clf.fit(X_train, y_train)

# Predict on the training and test data
y_train_pred = best_rf_clf.predict(X_train)
y_test_pred = best_rf_clf.predict(X_test)

# Calculate accuracy scores
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

# Print the accuracy scores
print("Test Accuracy:", train_accuracy)
print("Training Accuracy:", test_accuracy)




# Print the best parameters found by GridSearchCV
print("Best Parameters:", grid_search.best_params_)
# Out:
# Test Accuracy: 0.8367346938775511
# Training Accuracy: 0.75
# Best Parameters: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
import numpy as np

# Splitting the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(df1.drop('Liver_Disease', axis=1), df1['Liver_Disease'], test_size=0.3, random_state=42)

# Defining the parameter distributions for RandomizedSearchCV
param_dist = {
    'n_estimators': [100, 200, 300, 400, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [10, 25, 50, None],
    'min_samples_split': np.arange(2, 21),
    'min_samples_leaf': np.arange(1, 16)
}

# Creating an instance of the Random Forest classifier
forest = RandomForestClassifier(random_state=42)

# Performing randomized search to find the best parameters
random_search = RandomizedSearchCV(estimator=forest, param_distributions=param_dist, cv=5, scoring='accuracy', n_iter=100, random_state=42, n_jobs=-1)
random_search.fit(X_train, y_train)

# Obtaining the best parameters and the best model
best_params = random_search.best_params_
best_model = random_search.best_estimator_

# Fitting the best model to the training data
best_model.fit(X_train, y_train)

# Predicting on the training and test sets
y_train_pred = best_model.predict(X_train)
y_test_pred = best_model.predict(X_test)

# %%
print('Precision:', precision_score(y_test, y_test_pred))
print('Recall:', recall_score(y_test, y_test_pred))
print('F1 Score:', f1_score(y_test, y_test_pred))
# Out:
# Precision: 0.47058823529411764
# Recall: 0.2
# F1 Score: 0.2807017543859649

# %%
# Confusion matrix
print('\nRandom Forest + Optimization Confusion Matrix:')
print(confusion_matrix(y_test, y_test_pred))
# Out:
# Random Forest + Optimization Confusion Matrix:
# [[119   9]
#  [ 32   8]]

# %%
import numpy as np
from sklearn.metrics import roc_curve, auc

# Assuming you have trained and fitted a Random Forest Classifier stored in best_rf_clf
# and you have test data stored in X_test and true labels stored in y_test

# Convert X_test DataFrame to a NumPy array
X_test_array = X_test.values

# Reshape X_test_array to have two dimensions
X_test_2d = X_test_array.reshape(X_test_array.shape[0], -1)

# Calculate and print the AUC
rf_y_test_prob = best_rf_clf.predict_proba(X_test_2d)[:, 1]
rf_false_positive_rate, rf_true_positive_rate, rf_thresholds = roc_curve(y_test, rf_y_test_prob)
RF_auc = auc(rf_false_positive_rate, rf_true_positive_rate)
print(f"Random Forest AUC: {RF_auc:.4f}")
# Out:
# Random Forest AUC: 0.7746

# %%
import matplotlib.pyplot as plt

# Calculate the false positive rate, true positive rate, and thresholds
fpr, tpr, thresholds = roc_curve(y_test, rf_y_test_prob)

# Calculate the area under the ROC curve (AUC)
RFC_score = auc(fpr, tpr)

# Print the AUC score
print(f"RFC Score: {RFC_score:.4f}")

# Plot the ROC curve
plt.figure()
plt.plot(fpr, tpr, label=f'Random Forest (AUC = {RFC_score:.4f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line for random classifier
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# RFC Score: 0.7746

# %% [markdown]
# # SVM Enhancement

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
# Load the dataset
liver_final = df1.copy()

# Split the data into features and target
X = liver_final.drop(['Liver_Disease'], axis=1)
y = liver_final['Liver_Disease']

# %%
# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Perform feature scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Define the parameter grid for GridSearchCV
param_grid = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto']
}

# Instantiate the SVM classifier
svm_clf = SVC(random_state=42)

# Perform grid search to find the best hyperparameters
grid_search = GridSearchCV(svm_clf, param_grid, cv=5)
grid_search.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(random_state=42),
#              param_grid={'C': [0.1, 1, 10], 'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
# Get the best estimator from the grid search
best_svm_clf = grid_search.best_estimator_

# Fit the best model on the scaled training data
best_svm_clf.fit(X_train_scaled, y_train)

# Predict on the scaled training and test data
y_train_pred = best_svm_clf.predict(X_train_scaled)
y_test_pred = best_svm_clf.predict(X_test_scaled)

# %%
# Calculate accuracy scores
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

# Print the accuracy scores
print("Training Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)

# Print the best parameters found by GridSearchCV
print("Best Parameters:", grid_search.best_params_)
# Out:
# Training Accuracy: 0.7168367346938775
# Test Accuracy: 0.7619047619047619
# Best Parameters: {'C': 0.1, 'gamma': 'scale', 'kernel': 'poly'}

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Calculate precision, recall, and F1 score
precision = precision_score(y_test, y_test_pred)
recall = recall_score(y_test, y_test_pred)
f1 = f1_score(y_test, y_test_pred)

# Print the precision, recall, and F1 score
print("Precision:", precision)
print("Recall:", recall)
print("F1 score:", f1)
# Out:
# Precision: 0.5
# Recall: 0.1
# F1 score: 0.16666666666666669

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the confusion matrix
confusion_mat = confusion_matrix(y_test, y_test_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

# Calculate the predicted probabilities for the positive class
y_test_prob = best_svm_clf.decision_function(X_test_scaled)

# Calculate the false positive rate, true positive rate, and thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_test_prob)

# Calculate the AUC score
SVM_score = auc(fpr, tpr)

# Print the AUC score
print(f"SVM Score: {SVM_score:.4f}")

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'SVM (AUC = {SVM_score:.4f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line for random classifier
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# SVM Score: 0.7342

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
# Load the dataset
liver_final = df1.copy()

# Split the data into features and target
X = liver_final.drop(['Liver_Disease'], axis=1)
y = liver_final['Liver_Disease']

# %%
# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Perform feature scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Define the parameter grid for GridSearchCV
param_grid = {
    'n_neighbors': [3, 5, 7],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

# Instantiate the KNN classifier
knn_clf = KNeighborsClassifier()

# %%
# Perform grid search to find the best hyperparameters
grid_search = GridSearchCV(knn_clf, param_grid, cv=5)
grid_search.fit(X_train_scaled, y_train)

# Get the best estimator from the grid search
best_knn_clf = grid_search.best_estimator_

# Fit the best model on the scaled training data
best_knn_clf.fit(X_train_scaled, y_train)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=7, weights='distance')

# %%
# Predict on the scaled training and test data
y_train_pred = best_knn_clf.predict(X_train_scaled)
y_test_pred = best_knn_clf.predict(X_test_scaled)

# Calculate accuracy scores
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

# %%
from sklearn.neighbors import KNeighborsClassifier

# Instantiate the KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)  # Specify the number of neighbors as needed

# Train the KNN classifier
knn.fit(X_train, y_train)

# Calculate and print the training and test accuracies
train_accuracy = knn.score(X_train, y_train)
test_accuracy = knn.score(X_test, y_test)
print("Training Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)

# Make predictions on the training set
y_train_pred = knn.predict(X_train)

# Rest of your code...
# Out:
# Training Accuracy: 0.75
# Test Accuracy: 0.7202380952380952

# %%
# Calculate precision, recall, and F1 score
precision = precision_score(y_test, y_test_pred)
recall = recall_score(y_test, y_test_pred)
f1 = f1_score(y_test, y_test_pred)

# %%
print("Precision Score:", precision)
print("Recall Score:", recall)
print("F1 Score:", f1)
# Out:
# Precision Score: 0.4230769230769231
# Recall Score: 0.55
# F1 Score: 0.47826086956521735

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
liver_final = df1.copy()

# Split the data into features and target
X = liver_final.drop(['Liver_Disease'], axis=1)
y = liver_final['Liver_Disease']

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Perform feature scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define the parameter grid for GridSearchCV
param_grid = {
    'n_neighbors': [3, 5, 7],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

# Instantiate the KNN classifier
knn_clf = KNeighborsClassifier()

# Perform grid search to find the best hyperparameters
grid_search = GridSearchCV(knn_clf, param_grid, cv=5)
grid_search.fit(X_train_scaled, y_train)

# Get the best estimator from the grid search
best_knn_clf = grid_search.best_estimator_

# Fit the best model on the scaled training data
best_knn_clf.fit(X_train_scaled, y_train)

# Predict on the scaled test data
y_test_pred = best_knn_clf.predict(X_test_scaled)

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_test_pred)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# Calculate the predicted probabilities for the positive class
y_test_prob = best_knn_clf.predict_proba(X_test_scaled)[:, 1]

# Calculate the false positive rate, true positive rate, and thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_test_prob)

# Calculate the AUC score
knn_score = auc(fpr, tpr)

# Print the AUC score
print(f"KNN Score: {knn_score:.4f}")

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'KNN (AUC = {knn_score:.4f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line for random classifier
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# KNN Score: 0.7524

# %% [markdown]
# # Enhanced Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
liver_final = df1.copy()

# Split the data into features and target
X = liver_final.drop(['Liver_Disease'], axis=1)
y = liver_final['Liver_Disease']

# %%
# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define the parameter grid for GridSearchCV
param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 5],
    'max_features': ['auto', 'sqrt', 'log2']
}

# %%
# Instantiate the decision tree classifier
dt_clf = DecisionTreeClassifier(random_state=42)

# Perform grid search to find the best hyperparameters
grid_search = GridSearchCV(dt_clf, param_grid, cv=5)
grid_search.fit(X_train, y_train)

# Get the best estimator from the grid search
best_dt_clf = grid_search.best_estimator_

# %%
# Perform feature selection
feature_selector = SelectFromModel(best_dt_clf, threshold='mean')
X_train_selected = feature_selector.fit_transform(X_train, y_train)
X_test_selected = feature_selector.transform(X_test)

# Fit the best model on the selected features
best_dt_clf.fit(X_train_selected, y_train)

# Predict on the test data
y_pred = best_dt_clf.predict(X_test_selected)

# %%
# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Print evaluation metrics
print("Decision Tree Metrics:")
print(f" Test Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
# Out:
# Decision Tree Metrics:
#  Test Accuracy: 0.7083
# Precision: 0.2857
# Recall: 0.1500
# F1-Score: 0.1967

# %%
# Plot the confusion matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# Predict probabilities for the positive class
y_test_prob = best_dt_clf.predict_proba(X_test_selected)[:, 1]

# Calculate false positive rate, true positive rate, and thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_test_prob)

# Calculate the ROC AUC score
DT_auc = auc(fpr, tpr)

# Print the ROC AUC score
print(f"ROC AUC Score: {DT_auc:.4f}")

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'Decision Tree (AUC = {DT_auc:.4f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line for random classifier
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# ROC AUC Score: 0.6573

# %% [markdown]
# # Enhance LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import numpy as np

# Load the dataset
liver_final = df1.copy()

# %%
# Split the data into features and target
X = liver_final.drop(['Liver_Disease'], axis=1).values
y = liver_final['Liver_Disease'].values

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Reshape the input data for LSTM model
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
# Define the LSTM model
model = Sequential()
model.add(Bidirectional(LSTM(units=64, activation='relu', return_sequences=True), input_shape=(1, X.shape[1])))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(units=64, activation='relu')))
model.add(Dropout(0.2))
model.add(Dense(units=1, activation='sigmoid'))

# Compile the model
optimizer = Adam(lr=0.001)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32)

# Evaluate the model
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 8s 8ms/step - loss: 0.6863 - accuracy: 0.6505
# Epoch 2/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6665 - accuracy: 0.6786
# Epoch 3/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6355 - accuracy: 0.6786
# Epoch 4/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6074 - accuracy: 0.6786
# Epoch 5/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5970 - accuracy: 0.6786
# Epoch 6/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5827 - accuracy: 0.6786
# Epoch 7/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5754 - accuracy: 0.6786
# Epoch 8/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5708 - accuracy: 0.6862
# Epoch 9/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5566 - accuracy: 0.6913
# Epoch 10/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5467 - accuracy: 0.7117
# Epoch 11/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5442 - accuracy: 0.7092
# Epoch 12/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5440 - accuracy: 0.7015
# Epoch 13/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5415 - accuracy: 0.7041
# Epoch 14/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5387 - accuracy: 0.6990
# Epoch 15/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5441 - accuracy: 0.6939
# Epoch 16/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5381 - accuracy: 0.6964
# Epoch 17/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5396 - accuracy: 0.7041
# Epoch 18/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5511 - accuracy: 0.7015
# Epoch 19/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5344 - accuracy: 0.6964
# Epoch 20/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5434 - accuracy: 0.7092
# Epoch 21/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.5343 - accuracy: 0.6786
# Epoch 22/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5392 - accuracy: 0.7041
# Epoch 23/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5384 - accuracy: 0.7092
# Epoch 24/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5322 - accuracy: 0.7066
# Epoch 25/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5389 - accuracy: 0.7066
# Epoch 26/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5350 - accuracy: 0.7117
# Epoch 27/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5338 - accuracy: 0.7041
# Epoch 28/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5292 - accuracy: 0.7194
# Epoch 29/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5384 - accuracy: 0.7245
# Epoch 30/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5331 - accuracy: 0.6888
# Epoch 31/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5344 - accuracy: 0.7168
# Epoch 32/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5321 - accuracy: 0.7117
# Epoch 33/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5300 - accuracy: 0.7117
# Epoch 34/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5250 - accuracy: 0.6939
# Epoch 35/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5315 - accuracy: 0.7092
# Epoch 36/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5291 - accuracy: 0.7015
# Epoch 37/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5251 - accuracy: 0.7168
# Epoch 38/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5285 - accuracy: 0.7117
# Epoch 39/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5276 - accuracy: 0.7143
# Epoch 40/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5221 - accuracy: 0.7117
# Epoch 41/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5323 - accuracy: 0.7041
# Epoch 42/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5316 - accuracy: 0.6990
# Epoch 43/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5285 - accuracy: 0.7245
# Epoch 44/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5237 - accuracy: 0.7168
# Epoch 45/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5220 - accuracy: 0.7245
# Epoch 46/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5233 - accuracy: 0.7194
# Epoch 47/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5323 - accuracy: 0.6964
# Epoch 48/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5211 - accuracy: 0.7041
# Epoch 49/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5265 - accuracy: 0.7194
# Epoch 50/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5251 - accuracy: 0.7245
# Epoch 51/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5210 - accuracy: 0.7117
# Epoch 52/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5299 - accuracy: 0.7168
# Epoch 53/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5226 - accuracy: 0.7117
# Epoch 54/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5269 - accuracy: 0.7296
# Epoch 55/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5232 - accuracy: 0.7041
# Epoch 56/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.5224 - accuracy: 0.7143
# Epoch 57/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5207 - accuracy: 0.7219
# Epoch 58/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5301 - accuracy: 0.7041
# Epoch 59/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5199 - accuracy: 0.7321
# Epoch 60/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5232 - accuracy: 0.7168
# Epoch 61/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5273 - accuracy: 0.7245
# Epoch 62/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5263 - accuracy: 0.7117
# Epoch 63/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5224 - accuracy: 0.7143
# Epoch 64/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5234 - accuracy: 0.7117
# Epoch 65/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.5161 - accuracy: 0.7117
# Epoch 66/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5214 - accuracy: 0.7066
# Epoch 67/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5207 - accuracy: 0.7194
# Epoch 68/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5181 - accuracy: 0.7245
# Epoch 69/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5248 - accuracy: 0.7194
# Epoch 70/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5204 - accuracy: 0.7219
# Epoch 71/100
# 13/13 [==============================] - 0s 11ms/step - loss: 0.5275 - accuracy: 0.7168
# Epoch 72/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5140 - accuracy: 0.7398
# Epoch 73/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5243 - accuracy: 0.7041
# Epoch 74/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5242 - accuracy: 0.7092
# Epoch 75/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5139 - accuracy: 0.7219
# Epoch 76/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5184 - accuracy: 0.7219
# Epoch 77/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5196 - accuracy: 0.7143
# Epoch 78/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5166 - accuracy: 0.7245
# Epoch 79/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5135 - accuracy: 0.7168
# Epoch 80/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.5175 - accuracy: 0.7117
# Epoch 81/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5160 - accuracy: 0.7219
# Epoch 82/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5192 - accuracy: 0.7245
# Epoch 83/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5151 - accuracy: 0.7168
# Epoch 84/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5115 - accuracy: 0.7245
# Epoch 85/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.5215 - accuracy: 0.7245
# Epoch 86/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.5181 - accuracy: 0.7194
# Epoch 87/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5193 - accuracy: 0.7245
# Epoch 88/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5105 - accuracy: 0.7347
# Epoch 89/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5131 - accuracy: 0.7270
# Epoch 90/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5147 - accuracy: 0.7270
# Epoch 91/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5074 - accuracy: 0.7347
# Epoch 92/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5127 - accuracy: 0.7270
# Epoch 93/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5176 - accuracy: 0.7143
# Epoch 94/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5185 - accuracy: 0.7194
# Epoch 95/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5117 - accuracy: 0.7168
# Epoch 96/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5229 - accuracy: 0.7168
# Epoch 97/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5198 - accuracy: 0.7168
# Epoch 98/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5159 - accuracy: 0.7270
# Epoch 99/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5161 - accuracy: 0.7219
# Epoch 100/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.5150 - accuracy: 0.7296

# %%
# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

# Print evaluation metrics
print("Enhanced LSTM Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
# Out:
# Enhanced LSTM Metrics:
# Accuracy: 0.7381
# Precision: 0.4167
# Recall: 0.2500
# F1-Score: 0.3125

# %%
# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %%
# Calculate false positive rate, true positive rate, and thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
# Calculate the AUC score
lstm_score = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'LSTM (AUC = {lstm_score:.4f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line for random classifier
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Print the AUC score
print(f"LSTM AUC Score: {lstm_score:.4f}")
# Out:
# LSTM AUC Score: 0.7727

# %%
# creating no skill line
ns_probs = [0 for _ in range(len(y_test))]
ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)

plt.figure(figsize=(20,15))
plt.title('ROC/AUC Curves',fontsize=30)
# plot the roc curve for the model
plt.plot(ns_fpr, ns_tpr, color='black', linestyle='--', label='No Skill')
plt.plot(svm_false_positive_rate, svm_true_positive_rate, color='red', linestyle='-', marker='.', label='SVM (auc = %0.7f)' % SVM_score)
plt.plot(knn_false_positive_rate, knn_true_positive_rate, color='green', linestyle='-', marker='*', label='KNN (auc = %0.7f)' % knn_score)
plt.plot(dt_false_positive_rate, dt_true_positive_rate, color='limegreen', linestyle='-', marker='+', label='Decision Tree (auc = %0.7f)' % DT_auc)
plt.plot(rf_false_positive_rate, rf_true_positive_rate, color='orange', linestyle='-', marker='.', label='Random Forest (auc = %0.8f)' % RFC_score)
plt.plot(lstm_false_positive_rate, lstm_true_positive_rate, color='purple', linestyle='-', marker='*', label='LSTM (auc = %0.7f)' % lstm_score)


# axis labels
plt.xlabel('False Positive Rate', fontsize=20)
plt.ylabel('True Positive Rate', fontsize=20)

# show the legend
plt.legend(prop={'size': 20})


# show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the model names and corresponding accuracies
models = ['SVM', 'KNN', 'Decision Tree', 'Random Forest', 'LSTM']
accuracies = [0.73, 0.72, 0.66, 0.75, 0.73]

# Set the positions of the bars on the x-axis
x_pos = range(len(models))

# Create the bar plot
plt.figure(figsize=(10, 6))
plt.bar(x_pos, accuracies, color='brown')

# Add labels and title
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Comparison of Accuracies for Different Models')
plt.xticks(x_pos, models)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the model names and corresponding AUC scores
models = ['SVM', 'KNN', 'Decision Tree', 'Random Forest', 'LSTM']
auc_scores = [0.56171875, 0.6359375, 0.5921875, 0.6296875, 0.75]

# Create the bar plot
plt.figure(figsize=(8, 6))
plt.bar(models, auc_scores, color='orange')

# Add labels and title
plt.xlabel('Models')
plt.ylabel('AUC Score')
plt.title('Comparison of AUC Scores for Different Models')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the model names and corresponding accuracies before and after enhancement
models = ['SVM', 'KNN', 'Decision Tree', 'Random Forest', 'LSTM']
accuracy_before = [0.73, 0.72, 0.66, 0.75, 0.73]
accuracy_after = [0.76, 0.72, 0.70, 0.83, 0.72]

# Set the positions of the bars on the x-axis
x_pos = range(len(models))

# Set the width of the bars
bar_width = 0.35

# Create the bar plot for accuracy before enhancement
plt.figure(figsize=(10, 6))
plt.bar(x_pos, accuracy_before, width=bar_width, color='purple', label='Before Enhancement')

# Create the bar plot for accuracy after enhancement
plt.bar([x + bar_width for x in x_pos], accuracy_after, width=bar_width, color='grey', label='After Enhancement')

# Add labels and title
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Comparison of Accuracies Before and After Enhancement for Different Models')
plt.xticks([x + bar_width/2 for x in x_pos], models)

# Add a legend
plt.legend()

# Show the plot
plt.show()
